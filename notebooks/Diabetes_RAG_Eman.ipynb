# %% [markdown]
# # Diabetes RAG – Ingestion, Chunking, Embeddings & Retrieval
#
# Loads the two diabetes guideline PDFs from GitHub, cleans and organizes them by section, creates page-aware chunks, stores embeddings in Chroma, and tests retrieval.

# %% [markdown]
# ## 1. Download the PDFs from GitHub

# %%
# !git clone https://github.com/Nourmohamed904/Diabetes_RAG_Hackathon.git
# Out:
# fatal: destination path 'Diabetes_RAG_Hackathon' already exists and is not an empty directory.

# %%
import os

PDF_FOLDER = "/content/Diabetes_RAG_Hackathon/data"

if not os.path.isdir(PDF_FOLDER):
    raise FileNotFoundError(
        f"PDF folder not found: {PDF_FOLDER}\n"
        "Check the repository structure or update PDF_FOLDER."
    )

PDF_PATHS = sorted(
    os.path.join(PDF_FOLDER, file)
    for file in os.listdir(PDF_FOLDER)
    if file.lower().endswith(".pdf")
)

print("Number of PDFs:", len(PDF_PATHS))
for pdf in PDF_PATHS:
    print("-", os.path.basename(pdf))
# Out:
# Number of PDFs: 2
# - Type-1 diabetes.pdf
# - Type-2 diabetes.pdf

# %% [markdown]
# ## 2. Install and import the required libraries

# %%
# !pip install -q langchain langchain-community langchain-text-splitters langchain-chroma chromadb fastembed pypdf

# %%
import os
import re
import shutil
from collections import Counter

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
# Out:
# /tmp/ipykernel_4412/1583142254.py:6: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# ## 3. Load the PDFs and add metadata

# %%
all_pages = []

for pdf_path in PDF_PATHS:
    loader = PyPDFLoader(pdf_path)
    pages = loader.load()
    document_name = os.path.basename(pdf_path)

    for page in pages:
        page.metadata["document_name"] = document_name
        page.metadata["page_number"] = page.metadata.get("page", 0) + 1

    all_pages.extend(pages)

print("Total PDFs:", len(PDF_PATHS))
print("Total pages:", len(all_pages))
# Out:
# Total PDFs: 2
# Total pages: 195

# %% [markdown]
# ## 4. Clean the extracted text

# %%
def clean_text(text):
    text = text.replace("\u00a0", " ")
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n[ \t]+", "\n", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    return text.strip()

for page in all_pages:
    page.page_content = clean_text(page.page_content)

print("Cleaning completed.")
# Out:
# Cleaning completed.

# %% [markdown]
# ### 4b. Remove repeated boilerplate (copyright footer / page-of-64 lines)
#
# Every page repeats the same NICE copyright notice and a "Page X of NN" footer, and often the guideline title as a running header. This text carries no medical meaning, but it gets embedded into every chunk that touches a page boundary, diluting the chunk's embedding and pushing genuinely relevant chunks further down the similarity ranking. Stripping it before chunking keeps each chunk focused on actual guideline content.

# %%
BOILERPLATE_PATTERNS = [
    r"©\s*NICE\s*\d{4}\.\s*All rights reserved\..*?notice-of-rights\)\.?",
    r"Page\s+\d+\s+of\s*\n?\s*\d+",
    r"Type 1 diabetes in adults: diagnosis and management \(NG17\)",
    r"Type 2 diabetes in adults: management \(NG28\)",
]

_boilerplate_regex = re.compile(
    "|".join(f"(?:{p})" for p in BOILERPLATE_PATTERNS),
    flags=re.DOTALL | re.IGNORECASE,
)


def remove_boilerplate(text):
    text = _boilerplate_regex.sub(" ", text)
    # Collapse whitespace left behind by the removals
    text = re.sub(r"[ \t]+", " ", text)
    text = re.sub(r"\n{3,}", "\n\n", text)
    return text.strip()


sample_before = all_pages[16].page_content  # page 17, has the footer

for page in all_pages:
    page.page_content = remove_boilerplate(page.page_content)

sample_after = all_pages[16].page_content

print("===== BEFORE boilerplate removal =====")
print(sample_before[-400:])
print("\n===== AFTER boilerplate removal =====")
print(sample_after[-400:])
print("\nBoilerplate removal applied to all", len(all_pages), "pages")
# Out:
# ===== BEFORE boilerplate removal =====
# ence in adult NHS services.
# [2015]
# 1.6.5 If HbA1c monitoring is invalid because of disturbed erythrocyte turnover or
# abnormal haemoglobin type, estimate trends in blood glucose control using 1 of
# Type 1 diabetes in adults: diagnosis and management (NG17)
# © NICE 2026. All rights reserved. Subject to Notice of rights (https://www.nice.org.uk/terms-and-
# conditions#notice-of-rights).
# Page 17 of
# 64
#
# ===== AFTER boilerplate removal =====
# th type 1 diabetes their HbA1c results after each measurement and
# have their most recent result available at consultations. Follow the principles on
# communication in NICE's guideline on patient experience in adult NHS services.
# [2015]
# 1.6.5 If HbA1c monitoring is invalid because of disturbed erythrocyte turnover or
# abnormal haemoglobin type, estimate trends in blood glucose control using 1 of
#
# Boilerplate removal applied to all 195 pages

# %%
print("Document:", all_pages[0].metadata["document_name"])
print("Page:", all_pages[0].metadata["page_number"])
print("\nSample text:\n")
print(all_pages[0].page_content[:1500])
# Out:
# Document: Type-1 diabetes.pdf
# Page: 1
#
# Sample text:
#
# Type 1 diabetes in adults:
# diagnosis and management
# NICE guideline
# Published: 26 August 2015
# Last updated: 17 August 2022
# www.nice.org.uk/guidance/ng17

# %% [markdown]
# ## 5. Detect and clean section headings

# %%
def is_section_heading(line):
    line = line.strip()
    if not line:
        return False

    # Main sections such as 1.1, 1.2, 1.10
    pattern = r"^\d+\.\d+\s+.+"
    return bool(re.match(pattern, line))


def clean_section_heading(line):
    line = line.strip()

    # Example:
    # 1.1 Diagnosis and early care plan ............ 6
    # -> 1.1 Diagnosis and early care plan
    line = re.sub(r"\s*\.{3,}\s*\d+\s*$", "", line)

    return line.strip()

# %%
test_lines = [
    "1.1 Diagnosis and early care plan",
    "1.2 Support and individualised care",
    "1.10 Ketone monitoring and managing diabetic ketoacidosis",
    "1.1.1 Make an initial diagnosis of type 1 diabetes",
    "People with diabetes should..."
]

for line in test_lines:
    print(is_section_heading(line), "→", line)
# Out:
# True → 1.1 Diagnosis and early care plan
# True → 1.2 Support and individualised care
# True → 1.10 Ketone monitoring and managing diabetic ketoacidosis
# False → 1.1.1 Make an initial diagnosis of type 1 diabetes
# False → People with diabetes should...

# %% [markdown]
# ## 6. Group pages by section

# %%
# First real content page for each guideline.
# Update these values if the PDF versions change.
FIRST_CONTENT_PAGE = {
    "type-1-diabetes-in-adults-diagnosis-and-management-pdf-1837276469701 (2).pdf": 6,
    "type-2-diabetes-in-adults-management-pdf-1837338615493 (1).pdf": 7,
}


def group_pages_by_section(pages):
    grouped_sections = []
    current_section = None
    current_document = None
    current_pages = []

    for page in pages:
        document_name = page.metadata["document_name"]
        page_number = page.metadata["page_number"]

        # Skip cover / front matter / contents.
        if page_number < FIRST_CONTENT_PAGE.get(document_name, 1):
            continue

        for line in page.page_content.splitlines():
            line = line.strip()

            if not line:
                continue

            if is_section_heading(line):
                if current_section is not None:
                    grouped_sections.append({
                        "document_name": current_document,
                        "section": current_section,
                        "pages": current_pages.copy(),
                    })

                current_section = clean_section_heading(line)
                current_document = document_name

                # Keep the heading's page even when the heading is first.
                current_pages = [{
                    "page_number": page_number,
                    "text": "",
                }]

            elif current_section is not None:
                if (
                    not current_pages
                    or current_pages[-1]["page_number"] != page_number
                ):
                    current_pages.append({
                        "page_number": page_number,
                        "text": line,
                    })
                else:
                    if current_pages[-1]["text"]:
                        current_pages[-1]["text"] += "\n" + line
                    else:
                        current_pages[-1]["text"] = line

    if current_section is not None:
        grouped_sections.append({
            "document_name": current_document,
            "section": current_section,
            "pages": current_pages.copy(),
        })

    return grouped_sections

# %%
grouped_sections = group_pages_by_section(all_pages)

print("Number of grouped sections:", len(grouped_sections))

first_section = grouped_sections[0]
print("\nFirst section:")
print("Document:", first_section["document_name"])
print("Section:", first_section["section"])
print("Number of pages:", len(first_section["pages"]))
print("First page:", first_section["pages"][0]["page_number"])
# Out:
# Number of grouped sections: 118
#
# First section:
# Document: Type-1 diabetes.pdf
# Section: 1.1 Diagnosis and early care plan
# Number of pages: 1
# First page: 3

# %% [markdown]
# **Chunk size note:** originally 850/150. Lowered to **300/60** after diagnosing Q5 ("insulin plan" question): at 850 chars, recommendation 1.7.1 (insulin regimen) was sharing a chunk with the unrelated "Levemir discontinuation" notice right after it, diluting the chunk's embedding enough that it dropped out of the top-6 results. At 300 chars, 1.7.1 gets an isolated chunk. Verified this doesn't break the other working recommendations (1.6.6 HbA1c target, 1.13.1 metformin first-line) — both still land cleanly in their own chunks at this size.

# %% [markdown]
# ## 7. Create page-aware chunks

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=60,
    separators=["\n\n", "\n", ". ", " ", ""],
)


def create_all_chunks(grouped_sections, splitter):
    all_chunks = []
    chunk_counter = 1

    for section in grouped_sections:
        section_text = ""
        page_boundaries = []

        for page in section["pages"]:
            start_position = len(section_text)
            section_text += page["text"] + "\n"
            end_position = len(section_text)

            page_boundaries.append({
                "page_number": page["page_number"],
                "start": start_position,
                "end": end_position,
            })

        if not page_boundaries:
            continue

        section_chunks = splitter.split_text(section_text)
        search_start = 0

        for chunk_text in section_chunks:
            chunk_start = section_text.find(chunk_text, search_start)
            if chunk_start == -1:
                chunk_start = search_start

            chunk_end = chunk_start + len(chunk_text)

            chunk_pages = [
                boundary["page_number"]
                for boundary in page_boundaries
                if boundary["end"] > chunk_start
                and boundary["start"] < chunk_end
            ]

            if not chunk_pages:
                chunk_pages = [page_boundaries[0]["page_number"]]

            chunk = Document(
                page_content=chunk_text,
                metadata={
                    "document_name": section["document_name"],
                    "section": section["section"],
                    "page_number": chunk_pages[0],
                    "page_numbers": chunk_pages,
                    "chunk_id": f"chunk_{chunk_counter:04d}",
                },
            )

            all_chunks.append(chunk)
            chunk_counter += 1
            search_start = chunk_start + 1

    return all_chunks

# %%
chunks = create_all_chunks(grouped_sections, splitter)

print("Total chunks:", len(chunks))

for i, chunk in enumerate(chunks[:3], 1):
    print("=" * 80)
    print(f"CHUNK {i}")
    print("Text:", chunk.page_content[:500])
    print("Metadata:", chunk.metadata)
# Out:
# Total chunks: 1102
# ================================================================================
# CHUNK 1
# Text: Terms used in this guideline ................................................................................................................. 48
# Recommendations for research .................................................................................................49
# Metadata: {'document_name': 'Type-1 diabetes.pdf', 'section': '1.14 Managing complications', 'page_number': 3, 'page_numbers': [3], 'chunk_id': 'chunk_0001'}
# ================================================================================
# CHUNK 2
# Text: 1 Clinical features for distinguishing between type 1 diabetes and other types of diabetes ........ 49
# 2 The use of C-peptide in diagnosing diabetes ................................................................................. 49
# Metadata: {'document_name': 'Type-1 diabetes.pdf', 'section': '1.14 Managing complications', 'page_number': 3, 'page_numbers': [3], 'chunk_id': 'chunk_0002'}
# ================================================================================
# CHUNK 3
# Text: 3 Use of routinely collected real-world data to examine the effectiveness and cost
# effectiveness of continuous glucose monitoring ............................................................................... 50
# Metadata: {'document_name': 'Type-1 diabetes.pdf', 'section': '1.14 Managing complications', 'page_number': 3, 'page_numbers': [3], 'chunk_id': 'chunk_0003'}

# %% [markdown]
# ## 8. Validate chunk metadata

# %%
required_fields = [
    "document_name",
    "section",
    "page_number",
    "page_numbers",
    "chunk_id",
]

for i, chunk in enumerate(chunks):
    for field in required_fields:
        assert field in chunk.metadata, f"Missing '{field}' in chunk {i}"

chunk_ids = [chunk.metadata["chunk_id"] for chunk in chunks]
assert len(chunk_ids) == len(set(chunk_ids)), "Duplicate chunk IDs found"

print("Metadata validation passed.")
print("Unique chunks:", len(chunks))

document_counts = Counter(
    chunk.metadata["document_name"] for chunk in chunks
)

print("\nChunks per document:")
for document, count in document_counts.items():
    print("-", document, ":", count)
# Out:
# Metadata validation passed.
# Unique chunks: 1102
#
# Chunks per document:
# - Type-1 diabetes.pdf : 377
# - Type-2 diabetes.pdf : 725

# %% [markdown]
# ## 9. Generate embeddings and create the Chroma vector store

# %%
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings
from langchain_community.vectorstores import Chroma

embedding_model = FastEmbedEmbeddings(
    model_name="BAAI/bge-base-en-v1.5"
)

# Chroma metadata must use scalar values, so convert page_numbers to a string.
cleaned_chunks = []

for doc in chunks:
    clean_meta = {}

    for key, value in doc.metadata.items():
        if value is None:
            clean_meta[key] = ""
        elif isinstance(value, (str, int, float, bool)):
            clean_meta[key] = value
        else:
            clean_meta[key] = str(value)

    doc.metadata = clean_meta
    cleaned_chunks.append(doc)

persist_directory = "./chroma_db"

if os.path.exists(persist_directory):
    shutil.rmtree(persist_directory)

vector_db = Chroma.from_documents(
    documents=cleaned_chunks,
    embedding=embedding_model,
    persist_directory=persist_directory,
    collection_name="diabetes_educational_rag",
)

stored_count = vector_db._collection.count()

print("Input chunks :", len(chunks))
print("Stored vectors:", stored_count)

assert stored_count == len(chunks), "Chroma count does not match input chunks."
print("Chroma indexing completed successfully.")
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Input chunks : 1102
# Stored vectors: 1102
# Chroma indexing completed successfully.

# %% [markdown]
# ## 10. Retrieval test

# %%
def _extract_pages(chunk_pages, fallback_page):
    if isinstance(chunk_pages, list):
        return [
            int(p)
            for p in chunk_pages
            if str(p).strip().lstrip("-").isdigit()
        ]

    if isinstance(chunk_pages, str):
        found = re.findall(r"\d+", chunk_pages)
        if found:
            return [int(p) for p in found]

    return [fallback_page] if fallback_page is not None else []


def retrieve_with_similarity(question, k=4):
    return vector_db.similarity_search_with_relevance_scores(question, k=k)


def print_retrieval_results(question, k=4):
    results = retrieve_with_similarity(question, k=k)

    print(f"QUESTION: {question}\n")

    for rank, (doc, score) in enumerate(results, start=1):
        print(f"Rank {rank}")
        print("Document :", doc.metadata.get("document_name"))
        print("Page     :", doc.metadata.get("page_number"))
        print("Pages    :", doc.metadata.get("page_numbers"))
        print("Section  :", doc.metadata.get("section"))
        print("Chunk ID :", doc.metadata.get("chunk_id"))
        print("Score    :", round(score, 4))
        print("Text     :", doc.page_content[:500].replace("\n", " "), "...")
        print()

    return results

# %%
results = print_retrieval_results(
    "What are the diagnostic criteria for diabetes?",
    k=4,
)
# Out:
# QUESTION: What are the diagnostic criteria for diabetes?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0014
# Score    : 0.6632
# Text     : Initial diagnosis 1.1.1 Make an initial diagnosis of type 1 diabetes on clinical grounds in adults presenting with hyperglycaemia. Bear in mind that people with type 1 diabetes typically (but not always) have 1 or more of: • ketosis • rapid weight loss • age of onset under 50 years ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6, 7]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0015
# Score    : 0.6281
# Text     : • ketosis • rapid weight loss • age of onset under 50 years • body mass index (BMI) below 25 kg/m2 • personal and/or family history of autoimmune disease. [2015, amended 2022] 1.1.2 Do not use age or BMI alone to exclude or diagnose type 1 diabetes in adults. [2022] ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 8
# Pages    : [8]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0024
# Score    : 0.6018
# Text     : diabetes to develop a plan for their early care. This will generally require: • medical assessment to: － ensure the diagnosis is accurate (see recommendations 1.1.1 to 1.1.5) － ensure appropriate acute care is given when needed － review medicines and detect potentially associated disease ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 3
# Pages    : [3]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0002
# Score    : 0.6008
# Text     : 1 Clinical features for distinguishing between type 1 diabetes and other types of diabetes ........ 49 2 The use of C-peptide in diagnosing diabetes ................................................................................. 49 ...

# %% [markdown]
# **Note:** the test questions are now hardcoded directly in this notebook instead of parsed
# from `RAG_Test_Questions.pdf`. Parsing a PDF table with regex is fragile — it silently breaks
# (and produces `0/0` results) whenever the PDF's layout changes. Editing questions here is
# also easier: just edit the list below.

# %%
# Hardcoded test questions (replaces fragile PDF parsing of RAG_Test_Questions.pdf).
# Editing/adding questions here does not depend on any PDF table layout.

supported_questions = [
    {"number": 1,  "question": "What should my HbA1c number be if I have type 1 diabetes?", "expected_source": "type-1.pdf", "expected_page": 18, "expected_keywords": ["48", "6.5"]},
    {"number": 2,  "question": "How often should I get my HbA1c checked?", "expected_source": "type-1.pdf", "expected_page": 17, "expected_keywords": ["3 to 6 months"]},
    {"number": 3,  "question": "What are the signs that someone might have type 1 diabetes?", "expected_source": "type-1.pdf", "expected_page": 6, "expected_keywords": ["ketosis", "weight loss"]},
    {"number": 4,  "question": "Can a doctor tell I have type 1 diabetes just from my age or weight?", "expected_source": "type-1.pdf", "expected_page": 7, "expected_keywords": ["BMI"]},
    {"number": 5,  "question": "What kind of insulin plan do people with type 1 diabetes usually start with?", "expected_source": "type-1.pdf", "expected_page": 24, "expected_keywords": ["basal", "bolus"]},
    {"number": 6,  "question": "When do I need to check my blood sugar more than 10 times a day?", "expected_source": "type-1.pdf", "expected_page": 23, "expected_keywords": ["10 times"]},
    {"number": 7,  "question": "What should be done if someone with diabetes passes out from low blood sugar?", "expected_source": "type-1.pdf", "expected_page": 31, "expected_keywords": ["glucagon"]},
    {"number": 8,  "question": "What blood sugar level should I aim for before an operation?", "expected_source": "type-1.pdf", "expected_page": 38, "expected_keywords": ["5 to 8"]},
    {"number": 9,  "question": "How often should someone with type 2 diabetes get their HbA1c checked?", "expected_source": "type-2.pdf", "expected_page": 12, "expected_keywords": ["HbA1c"]},
    {"number": 10, "question": "Do I need to check my blood sugar every day if I have type 2 diabetes?", "expected_source": "type-2.pdf", "expected_page": 14, "expected_keywords": ["self-monitoring"]},
    {"number": 11, "question": "What's usually the first medicine given for type 2 diabetes?", "expected_source": "type-2.pdf", "expected_page": 32, "expected_keywords": ["metformin"]},
    {"number": 12, "question": "What treatment is given if someone has type 2 diabetes and a heart problem?", "expected_source": "type-2.pdf", "expected_page": 40, "expected_keywords": ["heart failure"]},
    {"number": 13, "question": "What treatment options are there for someone with type 2 diabetes who is overweight?", "expected_source": "type-2.pdf", "expected_page": 58, "expected_keywords": ["obesity"]},
    {"number": 14, "question": "What should be checked before starting SGLT-2 medicine?", "expected_source": "type-2.pdf", "expected_page": 70, "expected_keywords": ["SGLT-2"]},
    {"number": 15, "question": "Should I take aspirin to protect my heart if I have type 2 diabetes?", "expected_source": "type-2.pdf", "expected_page": 119, "expected_keywords": ["antiplatelet", "aspirin"]},
]

unsupported_questions = [
    {"number": 1, "question": "How much do diabetes medicines cost in Egypt?", "reason": "No pricing or local market info in either PDF"},
    {"number": 2, "question": "Is there a cure for diabetes now?", "reason": "Not mentioned in either guideline"},
    {"number": 3, "question": "Can people with type 1 diabetes take weight-loss injections like Ozempic?", "reason": "type-1.pdf does not cover this type of medicine at all"},
    {"number": 4, "question": "Will type 1 diabetes affect my chances of having children?", "reason": "type-1.pdf just points to a separate pregnancy guideline, no real answer given"},
    {"number": 5, "question": "Which brand of blood sugar monitor is the best one to buy?", "reason": "The guidelines don't recommend specific brands or products"},
]

print("Supported questions  :", len(supported_questions))
print("Unsupported questions:", len(unsupported_questions))
# Out:
# Supported questions  : 15
# Unsupported questions: 5

# %%
def check_match(results, expected_source, expected_page, expected_keywords=None,
                 page_tolerance=3):
    """
    Checks retrieval quality on two levels:
      1. Source + page match: did we retrieve a chunk from the right PDF, near the right page?
      2. Content match (optional): does that chunk actually contain the expected keyword(s)?
         This catches cases where the page number is right but the specific fact
         (e.g. "48 mmol/mol") isn't actually present in the retrieved text.
    Returns a dict so both signals are visible, instead of collapsing to one bool.
    """
    expected_source = (expected_source or "").lower()
    expected_tag = "type-1" if "type-1" in expected_source else "type-2"
    expected_keywords = [kw.lower() for kw in (expected_keywords or [])]

    page_match = False
    keyword_match = not expected_keywords  # True (vacuously) if no keywords were given

    for doc, _score in results:
        doc_name = doc.metadata.get("document_name", "").lower()
        chunk_pages = _extract_pages(
            doc.metadata.get("page_numbers"),
            doc.metadata.get("page_number"),
        )
        this_chunk_on_page = expected_tag in doc_name and any(
            abs(page - expected_page) <= page_tolerance
            for page in chunk_pages
        )

        if this_chunk_on_page:
            page_match = True
            if expected_keywords:
                chunk_text = doc.page_content.lower()
                if any(kw in chunk_text for kw in expected_keywords):
                    keyword_match = True

    return {
        "page_match": page_match,
        "keyword_match": keyword_match,
        "match": page_match and keyword_match,
    }


supported_hits = 0
page_only_hits = 0

print("===== SUPPORTED QUESTIONS =====\n")

for item in supported_questions:
    results = print_retrieval_results(item["question"], k=4)

    outcome = check_match(
        results,
        item["expected_source"],
        item["expected_page"],
        item.get("expected_keywords"),
    )

    supported_hits += outcome["match"]
    page_only_hits += outcome["page_match"] and not outcome["keyword_match"]

    if outcome["match"]:
        status = "MATCH"
    elif outcome["page_match"]:
        status = "PARTIAL (right page, keyword not found in retrieved text)"
    else:
        status = "NO MATCH"

    print(
        f"Expected: {item['expected_source']} p.{item['expected_page']} "
        f"-> {status}"
    )
    print("=" * 80)

print(f"Supported questions fully matched : {supported_hits}/{len(supported_questions)}")
print(f"Right page but keyword missing    : {page_only_hits}/{len(supported_questions)}")
# Out:
# ===== SUPPORTED QUESTIONS =====
#
# QUESTION: What should my HbA1c number be if I have type 1 diabetes?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 18
# Pages    : [18]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0080
# Score    : 0.7102
# Text     : 1.6.8 Ensure that aiming for an HbA1c target is not accompanied by problematic hypoglycaemia in adults with type 1 diabetes. [2015] 1.6.9 Diabetes services should document the proportion of adults with type 1 diabetes who reach an HbA1c level of 53 mmol/mol (7%) or lower. [2015] ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 29
# Pages    : [29]
# Section  : 1.7 Insulin therapy
# Chunk ID : chunk_0142
# Score    : 0.6784
# Text     : appraisal guidance for managing blood glucose levels in type 1 diabetes for adults who have an HbA1c of 58 mmol/mol (7.5%) or more, or have disabling hypoglycaemia, despite best possible management with at least 1 of the ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 17
# Pages    : [17]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0074
# Score    : 0.6731
# Text     : HbA1c measurement and targets Measurement 1.6.1 Measure HbA1c levels every 3 to 6 months in adults with type 1 diabetes. [2015] 1.6.2 Consider measuring HbA1c levels more often in adults with type 1 diabetes if their blood glucose control is suspected to be changing rapidly; for example, if their ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 18
# Pages    : [18]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0078
# Score    : 0.6707
# Text     : • quality-controlled blood glucose profiles • total glycated haemoglobin estimation (if abnormal haemoglobins). [2015] Targets 1.6.6 Support adults with type 1 diabetes to aim for a target HbA1c level of 48 mmol/ mol (6.5%) or lower, to minimise the risk of long-term vascular complications. [2015] ...
#
# Expected: type-1.pdf p.18 -> MATCH
# ================================================================================
# QUESTION: How often should I get my HbA1c checked?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 17
# Pages    : [17]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0074
# Score    : 0.7742
# Text     : HbA1c measurement and targets Measurement 1.6.1 Measure HbA1c levels every 3 to 6 months in adults with type 1 diabetes. [2015] 1.6.2 Consider measuring HbA1c levels more often in adults with type 1 diabetes if their blood glucose control is suspected to be changing rapidly; for example, if their ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 12
# Pages    : [12]
# Section  : 1.5 HbA1c measurement and targets
# Chunk ID : chunk_0426
# Score    : 0.7085
# Text     : Measurement 1.5.1 Measure HbA1c levels in adults with type 2 diabetes every: • 3 to 6 months (tailored to individual needs) until HbA1c is stable on unchanging therapy • 6 months once the HbA1c level and blood glucose lowering therapy are stable. [2015] ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 15
# Pages    : [15, 16]
# Section  : 1.7 Continuous glucose monitoring
# Chunk ID : chunk_0451
# Score    : 0.6475
# Text     : capillary blood glucose monitoring but could use an isCGM device (or have it scanned for them) • they would otherwise be advised to self-measure at least 8 times a day. For guidance on continuous glucose monitoring (CGM) in pregnancy, see NICE's guideline on diabetes in pregnancy. [2022] ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 22
# Pages    : [22]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0101
# Score    : 0.637
# Text     : least 4 times a day (including before each meal and before bed). [2015, amended 2022] 1.6.20 Support adults with type 1 diabetes who are using capillary blood glucose monitoring to measure at least 4 times a day, and up to 10 times a day: ...
#
# Expected: type-1.pdf p.17 -> MATCH
# ================================================================================
# QUESTION: What are the signs that someone might have type 1 diabetes?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0014
# Score    : 0.6521
# Text     : Initial diagnosis 1.1.1 Make an initial diagnosis of type 1 diabetes on clinical grounds in adults presenting with hyperglycaemia. Bear in mind that people with type 1 diabetes typically (but not always) have 1 or more of: • ketosis • rapid weight loss • age of onset under 50 years ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6, 7]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0015
# Score    : 0.6075
# Text     : • ketosis • rapid weight loss • age of onset under 50 years • body mass index (BMI) below 25 kg/m2 • personal and/or family history of autoimmune disease. [2015, amended 2022] 1.1.2 Do not use age or BMI alone to exclude or diagnose type 1 diabetes in adults. [2022] ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 3
# Pages    : [3]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0002
# Score    : 0.6025
# Text     : 1 Clinical features for distinguishing between type 1 diabetes and other types of diabetes ........ 49 2 The use of C-peptide in diagnosing diabetes ................................................................................. 49 ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 51
# Pages    : [51]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0267
# Score    : 0.6
# Text     : ketoacidosis. It is less harmful to be diagnosed with type 1 diabetes when the person actually has type 2 diabetes. However, there are still harms, including: • the long-term effects and costs of unnecessary insulin therapy • the missed opportunity for oral diabetes therapies ...
#
# Expected: type-1.pdf p.6 -> MATCH
# ================================================================================
# QUESTION: Can a doctor tell I have type 1 diabetes just from my age or weight?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6, 7]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0015
# Score    : 0.6899
# Text     : • ketosis • rapid weight loss • age of onset under 50 years • body mass index (BMI) below 25 kg/m2 • personal and/or family history of autoimmune disease. [2015, amended 2022] 1.1.2 Do not use age or BMI alone to exclude or diagnose type 1 diabetes in adults. [2022] ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0014
# Score    : 0.6737
# Text     : Initial diagnosis 1.1.1 Make an initial diagnosis of type 1 diabetes on clinical grounds in adults presenting with hyperglycaemia. Bear in mind that people with type 1 diabetes typically (but not always) have 1 or more of: • ketosis • rapid weight loss • age of onset under 50 years ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 7
# Pages    : [7, 8]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0021
# Score    : 0.6486
# Text     : type 1 diabetes increases the longer the test is done after initial diagnosis of diabetes. [2022] 1.1.9 For people aged 60 and over presenting with weight loss and new-onset diabetes, follow recommendations on assessing for pancreatic cancer in the ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 51
# Pages    : [51, 52]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0270
# Score    : 0.6147
# Text     : mass index (BMI) might be used in isolation. They noted that the average BMI in people with type 1 diabetes is increasing, and the age at which people are diagnosed with type 2 diabetes is decreasing. This means these clinical features are becoming less useful on ...
#
# Expected: type-1.pdf p.7 -> MATCH
# ================================================================================
# QUESTION: What kind of insulin plan do people with type 1 diabetes usually start with?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 24
# Pages    : [24]
# Section  : 1.7 Insulin therapy
# Chunk ID : chunk_0114
# Score    : 0.6455
# Text     : Insulin regimens 1.7.1 Offer multiple daily injection basal–bolus insulin regimens as the insulin injection regimen of choice for all adults with type 1 diabetes. Provide guidance on using this regimen. [2015] 1.7.2 Do not offer adults newly diagnosed with type 1 diabetes non-basal–bolus insulin ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 31
# Pages    : [31]
# Section  : 1.9 Hypoglycaemia awareness and management
# Chunk ID : chunk_0159
# Score    : 0.6315
# Text     : 1.9.12 Explain to adults with type 1 diabetes that: • it is very common to experience some hypoglycaemic episodes with any insulin regimen • they should use a regimen that avoids or reduces the frequency of hypoglycaemic episodes, while maintaining the most optimal blood glucose ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 6
# Pages    : [6]
# Section  : 1.1 Diagnosis and early care plan
# Chunk ID : chunk_0014
# Score    : 0.6188
# Text     : Initial diagnosis 1.1.1 Make an initial diagnosis of type 1 diabetes on clinical grounds in adults presenting with hyperglycaemia. Bear in mind that people with type 1 diabetes typically (but not always) have 1 or more of: • ketosis • rapid weight loss • age of onset under 50 years ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 27
# Pages    : [27]
# Section  : 1.7 Insulin therapy
# Chunk ID : chunk_0132
# Score    : 0.6094
# Text     : quality of life. [2015] Insulin injection delivery 1.7.15 For adults with type 1 diabetes who inject insulin, provide their preferred insulin injection delivery device (this often means using one or more types of insulin injection pen). [2004] ...
#
# Expected: type-1.pdf p.24 -> MATCH
# ================================================================================
# QUESTION: When do I need to check my blood sugar more than 10 times a day?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 22
# Pages    : [22]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0101
# Score    : 0.7234
# Text     : least 4 times a day (including before each meal and before bed). [2015, amended 2022] 1.6.20 Support adults with type 1 diabetes who are using capillary blood glucose monitoring to measure at least 4 times a day, and up to 10 times a day: ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 23
# Pages    : [23]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0104
# Score    : 0.7146
# Text     : NICE's guideline on diabetes in pregnancy) • if they need to know their blood glucose levels more than 4 times a day for other reasons (for example, impaired hypoglycaemia awareness, or they are undertaking high-risk activities). [2015, amended 2022] ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 23
# Pages    : [23]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0105
# Score    : 0.6996
# Text     : undertaking high-risk activities). [2015, amended 2022] 1.6.21 Enable additional blood glucose measurement (more than 10 times a day) for adults with type 1 diabetes who are using capillary blood glucose monitoring if this is necessary because of: ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 15
# Pages    : [15, 16]
# Section  : 1.7 Continuous glucose monitoring
# Chunk ID : chunk_0451
# Score    : 0.6908
# Text     : capillary blood glucose monitoring but could use an isCGM device (or have it scanned for them) • they would otherwise be advised to self-measure at least 8 times a day. For guidance on continuous glucose monitoring (CGM) in pregnancy, see NICE's guideline on diabetes in pregnancy. [2022] ...
#
# Expected: type-1.pdf p.23 -> MATCH
# ================================================================================
# QUESTION: What should be done if someone with diabetes passes out from low blood sugar?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 14
# Pages    : [14]
# Section  : 1.5 HbA1c measurement and targets
# Chunk ID : chunk_0440
# Score    : 0.6065
# Text     : and they are not experiencing hypoglycaemia, encourage them to maintain it. Be aware that there are other possible reasons for a low HbA1c level, for example deteriorating renal function or sudden weight loss. [2015] ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 34
# Pages    : [34]
# Section  : 1.10 Ketone monitoring and managing diabetic
# Chunk ID : chunk_0173
# Score    : 0.5992
# Text     : 1.10.8 When the plasma glucose concentration has fallen to 10 to 15 mmol/litre in adults with DKA, give glucose-containing fluids (not more than 2 litres in 24 hours) so that the insulin infusion can be continued at a sufficient rate to clear ketones (for ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 34
# Pages    : [34]
# Section  : 1.10 Ketone monitoring and managing diabetic
# Chunk ID : chunk_0172
# Score    : 0.5812
# Text     : rapidly except in cases of circulatory collapse. [2004] 1.10.6 Do not generally use bicarbonate for managing DKA in adults. [2004, amended 2015] 1.10.7 Give intravenous insulin by infusion to adults with DKA. [2004] ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 31
# Pages    : [31]
# Section  : 1.9 Hypoglycaemia awareness and management
# Chunk ID : chunk_0158
# Score    : 0.5757
# Text     : their level of consciousness is not improving significantly • then given oral carbohydrate when it is safe to administer it, and put under continued observation by someone who has been warned about the risk of relapse. [2004, amended 2015] 1.9.12 Explain to adults with type 1 diabetes that: ...
#
# Expected: type-1.pdf p.31 -> PARTIAL (right page, keyword not found in retrieved text)
# ================================================================================
# QUESTION: What blood sugar level should I aim for before an operation?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 38
# Pages    : [38]
# Section  : 1.13 Caring for adults with type 1 diabetes in
# Chunk ID : chunk_0196
# Score    : 0.6949
# Text     : hospital Blood glucose control 1.13.1 Aim for a target plasma glucose level of 5 to 8 mmol/litre for adults with type 1 diabetes during surgery or acute illness. [2015] 1.13.2 Establish a local protocol for controlling blood glucose levels in adults with type 1 ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 23
# Pages    : [23]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0107
# Score    : 0.6649
# Text     : Blood glucose targets 1.6.22 Advise adults with type 1 diabetes to aim for: • a fasting plasma glucose level of 5 to 7 mmol/litre on waking and • a plasma glucose level of 4 to 7 mmol/litre before meals at other times of the day. [2015] ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 23
# Pages    : [23]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0108
# Score    : 0.6503
# Text     : day. [2015] 1.6.23 Advise adults with type 1 diabetes who choose to measure after meals to aim for a plasma glucose level of 5 to 9 mmol/litre at least 90 minutes after eating. (This timing may be different in pregnancy – for guidance on plasma glucose targets in ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 13
# Pages    : [13]
# Section  : 1.5 HbA1c measurement and targets
# Chunk ID : chunk_0435
# Score    : 0.6166
# Text     : associated with hypoglycaemia, support them to aim for an HbA1c level of 53 mmol/mol (7.0%). [2015, amended 2026] 1.5.8 In adults with type 2 diabetes, if HbA1c levels are not adequately controlled by the initial medication regimen and rise to 58 mmol/mol (7.5%) or higher: ...
#
# Expected: type-1.pdf p.38 -> MATCH
# ================================================================================
# QUESTION: How often should someone with type 2 diabetes get their HbA1c checked?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 17
# Pages    : [17]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0074
# Score    : 0.7724
# Text     : HbA1c measurement and targets Measurement 1.6.1 Measure HbA1c levels every 3 to 6 months in adults with type 1 diabetes. [2015] 1.6.2 Consider measuring HbA1c levels more often in adults with type 1 diabetes if their blood glucose control is suspected to be changing rapidly; for example, if their ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 12
# Pages    : [12]
# Section  : 1.5 HbA1c measurement and targets
# Chunk ID : chunk_0426
# Score    : 0.7609
# Text     : Measurement 1.5.1 Measure HbA1c levels in adults with type 2 diabetes every: • 3 to 6 months (tailored to individual needs) until HbA1c is stable on unchanging therapy • 6 months once the HbA1c level and blood glucose lowering therapy are stable. [2015] ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 22
# Pages    : [22]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0101
# Score    : 0.6617
# Text     : least 4 times a day (including before each meal and before bed). [2015, amended 2022] 1.6.20 Support adults with type 1 diabetes who are using capillary blood glucose monitoring to measure at least 4 times a day, and up to 10 times a day: ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 113
# Pages    : [113]
# Section  : 1.37 Periodontitis
# Chunk ID : chunk_1002
# Score    : 0.6539
# Text     : and can reduce their risk of hyperglycaemia. [2022] 1.37.2 Advise adults with type 2 diabetes to have regular oral health reviews (their oral healthcare or dental team will tell them how often, in line with NICE's guideline on dental checks: intervals between oral health reviews). [2022] ...
#
# Expected: type-2.pdf p.12 -> MATCH
# ================================================================================
# QUESTION: Do I need to check my blood sugar every day if I have type 2 diabetes?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 14
# Pages    : [14]
# Section  : 1.6 Self-monitoring of capillary blood glucose
# Chunk ID : chunk_0443
# Score    : 0.6495
# Text     : capillary blood glucose levels for adults with type 2 diabetes. [2015, amended 2022] 1.6.2 Do not routinely offer self-monitoring of capillary blood glucose levels for adults with type 2 diabetes unless: • the person is on insulin or • there is evidence of hypoglycaemic episodes or ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 113
# Pages    : [113]
# Section  : 1.37 Periodontitis
# Chunk ID : chunk_1002
# Score    : 0.6466
# Text     : and can reduce their risk of hyperglycaemia. [2022] 1.37.2 Advise adults with type 2 diabetes to have regular oral health reviews (their oral healthcare or dental team will tell them how often, in line with NICE's guideline on dental checks: intervals between oral health reviews). [2022] ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 23
# Pages    : [23]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0104
# Score    : 0.6388
# Text     : NICE's guideline on diabetes in pregnancy) • if they need to know their blood glucose levels more than 4 times a day for other reasons (for example, impaired hypoglycaemia awareness, or they are undertaking high-risk activities). [2015, amended 2022] ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 16
# Pages    : [16]
# Section  : 1.7 Continuous glucose monitoring
# Chunk ID : chunk_0454
# Score    : 0.6355
# Text     : people to self-manage their diabetes. [2022] 1.7.5 Advise adults with type 2 diabetes who are using CGM that they will still need to take capillary blood glucose measurements (although they can do this less often). Explain that is because: ...
#
# Expected: type-2.pdf p.14 -> MATCH
# ================================================================================
# QUESTION: What's usually the first medicine given for type 2 diabetes?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 26
# Pages    : [26]
# Section  : 1.9 Involving people in medicine discussions
# Chunk ID : chunk_0517
# Score    : 0.6653
# Text     : agonist or tirzepatide and for a duration after taking it (this duration depends on the specific medicine the person takes). The committee noted this was particularly important for people with early onset type 2 diabetes because of their age and this ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 71
# Pages    : [71]
# Section  : 1.21 Preventing diabetic ketoacidosis when taking
# Chunk ID : chunk_0773
# Score    : 0.6621
# Text     : effects and intolerances from the first medicine to be identified before the second is introduced. In line with current practice, the committee recommended starting with metformin and then adding the SGLT-2 inhibitor without delay once metformin ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 69
# Pages    : [69]
# Section  : 1.20 Introducing medicines in a stepwise manner
# Chunk ID : chunk_0765
# Score    : 0.6613
# Text     : 1.20.1 Introduce medicines in a stepwise manner, checking for tolerability and effectiveness of each medicine. [2015] 1.20.2 When an adult with type 2 diabetes starts initial therapy with metformin and one or more other medicines: ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 129
# Pages    : [129]
# Section  : 1.45 Antiplatelet therapy
# Chunk ID : chunk_1086
# Score    : 0.6592
# Text     : Type 2 diabetes Path to Remission Programme. • Some recommendations have been amended to align them with the new medicine recommendations. This includes recommendations on HbA1c targets, that now refer to an 'initial medication regimen' rather than a 'single drug', and recommendations on ...
#
# Expected: type-2.pdf p.32 -> NO MATCH
# ================================================================================
# QUESTION: What treatment is given if someone has type 2 diabetes and a heart problem?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 41
# Pages    : [41]
# Section  : 1.14 People with heart failure (with any ejection
# Chunk ID : chunk_0601
# Score    : 0.6958
# Text     : as the standard initial treatment. There was limited evidence for people with type 2 diabetes and heart failure. However, for people with type 2 diabetes who are at high risk of developing cardiovascular disease, there was strong evidence that SGLT-2 inhibitors reduced the ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 75
# Pages    : [75]
# Section  : 1.23 Reviewing metformin
# Chunk ID : chunk_0794
# Score    : 0.6443
# Text     : person with type 2 diabetes. SGLT-2 inhibitors are a good treatment option for most people and provide cardiovascular and renal protection that cannot be measured by tests. Therefore, the committee agreed that these should be continued even if they do not help the person ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 21
# Pages    : [21, 22]
# Section  : 1.8 Hyperglycaemia
# Chunk ID : chunk_0491
# Score    : 0.6385
# Text     : 1.8.1 If an adult with type 2 diabetes has symptoms of hyperglycaemia, consider insulin (see the section on insulin-based treatments) or a sulfonylurea, and review treatment when blood glucose is within the targets set for the person. [2015] Person-centred medicine ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 40
# Pages    : [40]
# Section  : 1.14 People with heart failure (with any ejection
# Chunk ID : chunk_0596
# Score    : 0.6337
# Text     : fraction, unless specified) 1.14.1 For adults with type 2 diabetes and heart failure offer: • modified-release metformin, and • an SGLT-2 inhibitor. [2026] 1.14.2 If metformin is contraindicated or not tolerated, offer monotherapy with an SGLT-2 inhibitor. [2026] ...
#
# Expected: type-2.pdf p.40 -> MATCH
# ================================================================================
# QUESTION: What treatment options are there for someone with type 2 diabetes who is overweight?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 58
# Pages    : [58]
# Section  : 1.17 People living with obesity
# Chunk ID : chunk_0708
# Score    : 0.6437
# Text     : 1.17.1 For adults with type 2 diabetes who are living with obesity, offer: • modified-release metformin and • an SGLT-2 inhibitor. For a definition of obesity, see the section on classifying overweight and obesity in adults in NICE's guideline on overweight and obesity management. [2026] ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 11
# Pages    : [11, 12]
# Section  : 1.4 Bariatric surgery
# Chunk ID : chunk_0425
# Score    : 0.6417
# Text     : 1.4.1 For recommendations on bariatric surgery for people with recent-onset type 2 diabetes, see the section on surgical interventions in NICE's guideline on overweight and obesity management. [2015] Blood glucose management ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 59
# Pages    : [59]
# Section  : 1.17 People living with obesity
# Chunk ID : chunk_0716
# Score    : 0.6403
# Text     : The committee agreed that therapy combining metformin with an SGLT-2 inhibitor is the most clinically effective option for people living with obesity and recommended this as the standard initial treatment. SGLT-2 inhibitors were cost effective for people living with obesity. Data on health ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 59
# Pages    : [59]
# Section  : 1.17 People living with obesity
# Chunk ID : chunk_0713
# Score    : 0.64
# Text     : person with type 2 diabetes and their healthcare professionals. However, if weight reduction is the primary aim of the treatment, the committee agreed that healthcare professionals should follow NICE's guideline on overweight and obesity management instead of this guideline. ...
#
# Expected: type-2.pdf p.58 -> MATCH
# ================================================================================
# QUESTION: What should be checked before starting SGLT-2 medicine?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 70
# Pages    : [70]
# Section  : 1.21 Preventing diabetic ketoacidosis when taking
# Chunk ID : chunk_0768
# Score    : 0.7245
# Text     : SGLT-2 inhibitors 1.21.1 Before starting an SGLT-2 inhibitor, check whether the person may be at increased risk of diabetic ketoacidosis (DKA), for example if they: • have had a previous episode of DKA • are unwell with intercurrent illness • are at risk of dehydration or volume depletion ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 71
# Pages    : [71]
# Section  : 1.21 Preventing diabetic ketoacidosis when taking
# Chunk ID : chunk_0773
# Score    : 0.6831
# Text     : effects and intolerances from the first medicine to be identified before the second is introduced. In line with current practice, the committee recommended starting with metformin and then adding the SGLT-2 inhibitor without delay once metformin ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 71
# Pages    : [71]
# Section  : 1.21 Preventing diabetic ketoacidosis when taking
# Chunk ID : chunk_0776
# Score    : 0.6745
# Text     : The committee noted some particularly important safety considerations to take into account before an adult with type 2 diabetes starts on an SGLT-2 inhibitor. In the committee's experience there have been multiple instances of avoidable diabetes ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 69
# Pages    : [69]
# Section  : 1.20 Introducing medicines in a stepwise manner
# Chunk ID : chunk_0766
# Score    : 0.6657
# Text     : or more other medicines: • introduce the medicines one at a time, starting with metformin and checking tolerability • if using an SGLT-2 inhibitor, start this as soon as metformin is at the maximum tolerated dose • if using a GLP-1 receptor agonist or tirzepatide, start this as soon as the ...
#
# Expected: type-2.pdf p.70 -> MATCH
# ================================================================================
# QUESTION: Should I take aspirin to protect my heart if I have type 2 diabetes?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 35
# Pages    : [35]
# Section  : 1.12 Control of cardiovascular risk
# Chunk ID : chunk_0179
# Score    : 0.7261
# Text     : Aspirin 1.12.1 Do not offer aspirin for the primary prevention of cardiovascular disease in adults with type 1 diabetes. [2015] Identifying cardiovascular risk 1.12.2 Assess cardiovascular risk factors annually, including: ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 119
# Pages    : [119]
# Section  : 1.45 Antiplatelet therapy
# Chunk ID : chunk_1037
# Score    : 0.7114
# Text     : 1.45.1 Do not offer antiplatelet therapy (aspirin or clopidogrel) to adults with type 2 diabetes without cardiovascular disease. [2015] 1.45.2 For guidance on the primary and secondary prevention of cardiovascular disease ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 36
# Pages    : [36]
# Section  : 1.12 Control of cardiovascular risk
# Chunk ID : chunk_0185
# Score    : 0.5979
# Text     : 1.12.7 Provide intensive management for adults who have had myocardial infarction or stroke, according to relevant non-diabetes guidelines. For angina or other ischaemic heart disease, beta-blockers should be considered (for insulin use in ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 52
# Pages    : [52]
# Section  : 1.16 People with early onset type 2 diabetes
# Chunk ID : chunk_0667
# Score    : 0.5929
# Text     : holistically (in particular, cardiovascular and renal protection), rather than just HbA1c. Based on their experience, the committee agreed that people with early onset type 2 diabetes: • have a very high lifetime risk of cardiovascular and renal complications, and of dying from them, and ...
#
# Expected: type-2.pdf p.119 -> MATCH
# ================================================================================
# Supported questions fully matched : 13/15
# Right page but keyword missing    : 1/15

# %%
print("===== UNSUPPORTED QUESTIONS =====\n")

for item in unsupported_questions:
    results = print_retrieval_results(item["question"], k=4)
    top_score = results[0][1] if results else 0

    print("Why unsupported:", item["reason"])
    print("Top-1 similarity:", round(top_score, 4))
    print("=" * 80)
# Out:
# ===== UNSUPPORTED QUESTIONS =====
#
# QUESTION: How much do diabetes medicines cost in Egypt?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 54
# Pages    : [54]
# Section  : 1.16 People with early onset type 2 diabetes
# Chunk ID : chunk_0687
# Score    : 0.4971
# Text     : incremental cost-effectiveness ratio (ICER) approaching £20,000 per quality-adjusted life year (QALY) gained. Tirzepatide was not analysed for this population. The evidence for combination therapy with metformin and SGLT-2 inhibitors showed ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 125
# Pages    : [125]
# Section  : 1.45 Antiplatelet therapy
# Chunk ID : chunk_1065
# Score    : 0.4971
# Text     : incremental cost-effectiveness ratio (ICER) approaching £20,000 per quality-adjusted life year (QALY) gained. Tirzepatide was not analysed for this population. The evidence for combination therapy with metformin and SGLT-2 inhibitors showed ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 63
# Pages    : [63]
# Section  : 1.18 People with chronic kidney disease
# Chunk ID : chunk_0735
# Score    : 0.4612
# Text     : However, the committee agreed that people with an eGFR above 30 ml/min/1.73 m2 should see the same benefits from diabetes medicines as people without chronic kidney disease. In the health economic analysis, metformin and SGLT-2 inhibitors were ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 62
# Pages    : [62]
# Section  : 1.18 People with chronic kidney disease
# Chunk ID : chunk_0732
# Score    : 0.454
# Text     : and up to 30 ml/min/1.73 m2 , offer: • either dapagliflozin or empagliflozin and • a DPP-4 inhibitor. [2026] 1.18.3 For adults with type 2 diabetes and an eGFR below 20 ml/min/1.73 m2 , consider a DPP-4 inhibitor. [2026] ...
#
# Why unsupported: No pricing or local market info in either PDF
# Top-1 similarity: 0.4971
# ================================================================================
# QUESTION: Is there a cure for diabetes now?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 129
# Pages    : [129]
# Section  : 1.45 Antiplatelet therapy
# Chunk ID : chunk_1083
# Score    : 0.573
# Text     : Update information February 2026: We reviewed evidence on medicines for type 2 diabetes, for people with no relevant comorbidities as well as for people with common comorbidities. We made new and updated recommendations on metformin, SGLT-2 inhibitors, GLP-1 ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 114
# Pages    : [114]
# Section  : 1.37 Periodontitis
# Chunk ID : chunk_1005
# Score    : 0.5702
# Text     : and that non-surgical periodontal treatment can improve diabetes control. However, in the committee's experience, people with diabetes are often unaware of this and may not be having regular oral health reviews. To address this, the committee ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 4
# Pages    : [4]
# Section  : 1.31 People with frailty
# Chunk ID : chunk_0386
# Score    : 0.5692
# Text     : Insulin-based treatments .......................................................................................................... 107 ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 45
# Pages    : [45]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0236
# Score    : 0.5684
# Text     : symptoms improve over time. [2015] 1.14.30 Explain to adults with type 1 diabetes that the specific treatments for acute painful neuropathy resulting from rapid improvement of blood glucose control: • aim to make symptoms tolerable until the condition resolves ...
#
# Why unsupported: Not mentioned in either guideline
# Top-1 similarity: 0.573
# ================================================================================
# QUESTION: Can people with type 1 diabetes take weight-loss injections like Ozempic?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 48
# Pages    : [48]
# Section  : 1.15 People with atherosclerotic cardiovascular
# Chunk ID : chunk_0638
# Score    : 0.6143
# Text     : people have a contraindication to metformin, they should have monotherapy with an SGLT-2 inhibitor. Subcutaneous semaglutide Evidence showed that subcutaneous semaglutide (Ozempic) was the most cost- effective GLP-1 receptor agonist. This evidence was based on clinical benefits ...
#
# Rank 2
# Document : Type-2 diabetes.pdf
# Page     : 89
# Pages    : [89]
# Section  : 1.27 People with atherosclerotic cardiovascular
# Chunk ID : chunk_0868
# Score    : 0.5956
# Text     : • is cost effective. The evidence showed subcutaneous semaglutide (Ozempic), up to 1 mg once a week, was the most cost effective and clinically effective GLP-1 receptor agonist in terms of cardiovascular and renal protection, and weight reduction. Sulfonylureas and pioglitazone ...
#
# Rank 3
# Document : Type-2 diabetes.pdf
# Page     : 32
# Pages    : [32]
# Section  : 1.12 Addressing inequalities in use of SGLT-2
# Chunk ID : chunk_0547
# Score    : 0.5789
# Text     : includes liraglutide, dulaglutide, and semaglutide. For subcutaneous semaglutide (Ozempic), this only includes doses up to 1 mg once a week. SGLT-2 inhibitors and GLP-1 receptor agonists are recommended as much for their ...
#
# Rank 4
# Document : Type-2 diabetes.pdf
# Page     : 87
# Pages    : [87, 88, 89]
# Section  : 1.27 People with atherosclerotic cardiovascular
# Chunk ID : chunk_0866
# Score    : 0.5725
# Text     : • a sulfonylurea or • pioglitazone or • an insulin-based treatment (see the section on insulin-based treatments). [2026] Why the committee made these recommendations Subcutaneous semaglutide Subcutaneous semaglutide (Ozempic), up to 1 mg once a week, was recommended ...
#
# Why unsupported: type-1.pdf does not cover this type of medicine at all
# Top-1 similarity: 0.6143
# ================================================================================
# QUESTION: Will type 1 diabetes affect my chances of having children?
#
# Rank 1
# Document : Type-1 diabetes.pdf
# Page     : 59
# Pages    : [59, 60]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0335
# Score    : 0.6016
# Text     : oral health inequalities. Return to recommendations Context Type 1 diabetes affects over 370,000 adults in the UK. It results from destruction of the cells that normally make insulin. Loss of insulin secretion results in high blood glucose and ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 60
# Pages    : [60]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0336
# Score    : 0.556
# Text     : other metabolic and haematological abnormalities, which have both short-term and long-term adverse effects on health. Over years, type 1 diabetes causes tissue damage which, if not detected and managed early, can result in disability: blindness, kidney failure, periodontitis, and foot ulceration ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 51
# Pages    : [51]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0267
# Score    : 0.5343
# Text     : ketoacidosis. It is less harmful to be diagnosed with type 1 diabetes when the person actually has type 2 diabetes. However, there are still harms, including: • the long-term effects and costs of unnecessary insulin therapy • the missed opportunity for oral diabetes therapies ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 23
# Pages    : [23]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0109
# Score    : 0.5339
# Text     : pregnancy, see NICE's guideline on diabetes in pregnancy.) [2015] 1.6.24 Agree bedtime target plasma glucose levels with each adult with type 1 diabetes. Take into account the timing of their last meal of the day and the related insulin ...
#
# Why unsupported: type-1.pdf just points to a separate pregnancy guideline, no real answer given
# Top-1 similarity: 0.6016
# ================================================================================
# QUESTION: Which brand of blood sugar monitor is the best one to buy?
#
# Rank 1
# Document : Type-2 diabetes.pdf
# Page     : 16
# Pages    : [16]
# Section  : 1.7 Continuous glucose monitoring
# Chunk ID : chunk_0453
# Score    : 0.5716
# Text     : glucose. [2022] 1.7.3 Consider real-time continuous glucose monitoring (rtCGM) as an alternative to isCGM for adults with insulin-treated type 2 diabetes if it is available for the same or lower cost. [2022] 1.7.4 CGM should be provided by a team with expertise in its use, as part of supporting ...
#
# Rank 2
# Document : Type-1 diabetes.pdf
# Page     : 54
# Pages    : [54]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0291
# Score    : 0.5681
# Text     : advantage to recommending 1 specific device over another compared with standard self- monitoring of blood glucose. They concluded that the specific functionality of isCGM versus rtCGM devices should be discussed between the person and their healthcare ...
#
# Rank 3
# Document : Type-1 diabetes.pdf
# Page     : 18
# Pages    : [18]
# Section  : 1.6 Blood glucose management
# Chunk ID : chunk_0081
# Score    : 0.5678
# Text     : Continuous glucose monitoring 1.6.10 Offer adults with type 1 diabetes a choice of real-time continuous glucose monitoring (rtCGM) or intermittently scanned continuous glucose monitoring (isCGM, commonly referred to as 'flash'), based on their individual preferences, ...
#
# Rank 4
# Document : Type-1 diabetes.pdf
# Page     : 54
# Pages    : [54]
# Section  : 1.14 Managing complications
# Chunk ID : chunk_0290
# Score    : 0.554
# Text     : hypoglycaemia with CGM was included, both technologies were cost effective for the full population of adults with type 1 diabetes compared with standard self-monitoring of blood glucose. Based on the above factors and the evidence, the committee agreed that there was no ...
#
# Why unsupported: The guidelines don't recommend specific brands or products
# Top-1 similarity: 0.5716
# ================================================================================

# %% [markdown]
# ## Final status

# %%
print("===== RAG DAY 1 STATUS =====")
print("PDFs loaded       :", len(PDF_PATHS))
print("Pages loaded      :", len(all_pages))
print("Grouped sections  :", len(grouped_sections))
print("Chunks created    :", len(chunks))
print("Vectors stored    :", vector_db._collection.count())
print("Supported tests   :", len(supported_questions))
print("Unsupported tests :", len(unsupported_questions))
# Out:
# ===== RAG DAY 1 STATUS =====
# PDFs loaded       : 2
# Pages loaded      : 195
# Grouped sections  : 118
# Chunks created    : 1102
# Vectors stored    : 1102
# Supported tests   : 15
# Unsupported tests : 5

# %% [markdown]
# ## 12. Generation step (RAG answer, not just retrieval)
#
# Everything above only *retrieves* chunks. This section adds the missing piece: send the retrieved chunks to an LLM and have it answer **only from that text**, or say clearly that the answer is not in the provided documents. This is the real hallucination/abstention test — a low similarity score alone doesn't prove the final answer will be safe.

# %%
# !pip install -q groq

# %%
import os
from groq import Groq
from getpass import getpass

# Free API key, no credit card needed: sign up at https://console.groq.com
# then Settings -> API Keys -> Create API Key
GROQ_API_KEY = getpass("Enter your Groq API key: ")
client = Groq(api_key=GROQ_API_KEY)
# Out:
# Enter your Groq API key: ··········

# %%
RAG_SYSTEM_PROMPT = """You are a medical-guideline assistant. You answer ONLY using the
CONTEXT chunks provided below, which come from NICE diabetes guidelines (NG17 for type 1,
NG28 for type 2).

Rules:
1. Base your answer strictly on the CONTEXT. Do not use outside knowledge, even if you
   know the answer from general medical knowledge.
2. If the CONTEXT does not contain enough information to answer the question, reply
   exactly: "I don't have enough information in the provided documents to answer that."
   Do not guess, estimate, or fill gaps with general knowledge.
3. When you do answer, cite the source document and page number in parentheses, e.g.
   (type-1.pdf, p.18).
4. Keep the answer short and in plain language, as if speaking to a patient.
5. Never invent a page number, statistic, or recommendation that is not literally present
   in the CONTEXT.
"""


def build_context(results):
    """Formats retrieved (doc, score) pairs into a labeled context block for the LLM."""
    blocks = []
    for doc, _score in results:
        source = doc.metadata.get("document_name", "unknown")
        page = doc.metadata.get("page_number", "?")
        blocks.append(f"[Source: {source}, page {page}]\n{doc.page_content}")
    return "\n\n---\n\n".join(blocks)


def generate_answer(question, results, model="llama-3.3-70b-versatile"):
    context = build_context(results)
    user_message = f"CONTEXT:\n{context}\n\nQUESTION: {question}"

    response = client.chat.completions.create(
        model=model,
        max_tokens=300,
        messages=[
            {"role": "system", "content": RAG_SYSTEM_PROMPT},
            {"role": "user", "content": user_message},
        ],
    )
    return response.choices[0].message.content

# %% [markdown]
# ### Quick test: one supported question, one unsupported question

# %%
test_q = "What should my HbA1c number be if I have type 1 diabetes?"
results = retrieve_with_similarity(test_q, k=4)
answer = generate_answer(test_q, results)

print("QUESTION:", test_q)
print("\nANSWER:\n", answer)
# Out:
# QUESTION: What should my HbA1c number be if I have type 1 diabetes?
#
# ANSWER:
#  For type 1 diabetes, aim for an HbA1c target of 48 mmol/mol (6.5%) or lower to minimize the risk of long-term vascular complications (Type-1 diabetes.pdf, p.18).

# %%
test_q_unsupported = "How much do diabetes medicines cost in Egypt?"
results = retrieve_with_similarity(test_q_unsupported, k=4)
answer = generate_answer(test_q_unsupported, results)

print("QUESTION:", test_q_unsupported)
print("\nANSWER:\n", answer)
# Out:
# QUESTION: How much do diabetes medicines cost in Egypt?
#
# ANSWER:
#  I don't have enough information in the provided documents to answer that.

# %% [markdown]
# ### Full run: generation over all 15 supported + 5 unsupported questions
#
# For supported questions, check the answer actually states the fact (not just avoids the question). For unsupported questions, the answer should closely match the abstention sentence in the system prompt — any specific number, price, or recommendation appearing here is a hallucination.

# %%
ABSTAIN_PHRASE = "i don't have enough information"

print("===== GENERATION: SUPPORTED QUESTIONS =====\n")
for item in supported_questions:
    results = retrieve_with_similarity(item["question"], k=4)
    answer = generate_answer(item["question"], results)
    abstained = ABSTAIN_PHRASE in answer.lower()
    print(f"Q{item['number']}: {item['question']}")
    print("A:", answer)
    print("Abstained:", abstained, "<-- should be False for supported questions")
    print("=" * 80)
# Out:
# ===== GENERATION: SUPPORTED QUESTIONS =====
#
# Q1: What should my HbA1c number be if I have type 1 diabetes?
# A: You should aim for an HbA1c level of 48 mmol/mol (6.5%) or lower to minimize the risk of long-term vascular complications (Type-1 diabetes.pdf, p.18).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q2: How often should I get my HbA1c checked?
# A: For type 1 diabetes, you should get your HbA1c levels measured every 3 to 6 months (Type-1 diabetes.pdf, page 17). For type 2 diabetes, it's also every 3 to 6 months until your levels are stable, then every 6 months (Type-2 diabetes.pdf, page 12).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q3: What are the signs that someone might have type 1 diabetes?
# A: Someone might have type 1 diabetes if they have hyperglycaemia and 1 or more of the following: ketosis, rapid weight loss, are under 50 years old, have a low BMI (under 25 kg/m2), or have a personal or family history of autoimmune disease (Type-1 diabetes.pdf, page 6).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q4: Can a doctor tell I have type 1 diabetes just from my age or weight?
# A: No, a doctor should not use age or BMI alone to diagnose or exclude type 1 diabetes in adults (Type-1 diabetes.pdf, page 6).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q5: What kind of insulin plan do people with type 1 diabetes usually start with?
# A: People with type 1 diabetes are usually offered a multiple daily injection basal-bolus insulin regimen (type-1.pdf, p.24).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q6: When do I need to check my blood sugar more than 10 times a day?
# A: You need to check your blood sugar more than 10 times a day if necessary because of certain reasons, such as impaired hypoglycaemia awareness or undertaking high-risk activities (Type-1 diabetes.pdf, page 23).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q7: What should be done if someone with diabetes passes out from low blood sugar?
# A: If someone with diabetes passes out from low blood sugar, they should be given glucose-containing fluids or intravenous glucose, and then given oral carbohydrate when it is safe to administer it, and put under continued observation (Type-1 diabetes.pdf, page 31).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q8: What blood sugar level should I aim for before an operation?
# A: You should aim for a target plasma glucose level of 5 to 8 mmol/litre before an operation (Type-1 diabetes.pdf, page 38).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q9: How often should someone with type 2 diabetes get their HbA1c checked?
# A: For people with type 2 diabetes, HbA1c levels should be measured every 3 to 6 months until the levels are stable, and then every 6 months once the levels and therapy are stable (Type-2 diabetes.pdf, page 12).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q10: Do I need to check my blood sugar every day if I have type 2 diabetes?
# A: You don't need to routinely check your blood sugar levels every day if you have type 2 diabetes, unless you're on insulin or have had hypoglycaemic episodes (Type-2 diabetes.pdf, page 14).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q11: What's usually the first medicine given for type 2 diabetes?
# A: The first medicine given for type 2 diabetes is usually metformin (Type-2 diabetes.pdf, page 71).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q12: What treatment is given if someone has type 2 diabetes and a heart problem?
# A: For adults with type 2 diabetes and heart failure, the treatment offered is modified-release metformin and an SGLT-2 inhibitor (Type-2 diabetes.pdf, page 40). If metformin is not suitable, then an SGLT-2 inhibitor is given on its own (Type-2 diabetes.pdf, page 40).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q13: What treatment options are there for someone with type 2 diabetes who is overweight?
# A: For adults with type 2 diabetes who are living with obesity, the treatment options include:
# modified-release metformin and an SGLT-2 inhibitor (Type-2 diabetes.pdf, page 58).
#
# Note: The provided context does not explicitly mention treatment options for someone who is only overweight, but rather for those living with obesity. For overweight individuals, it's advised to refer to NICE's guideline on overweight and obesity management (Type-2 diabetes.pdf, page 11 and page 59).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q14: What should be checked before starting SGLT-2 medicine?
# A: Before starting an SGLT-2 inhibitor, check if the person may be at increased risk of diabetic ketoacidosis (DKA), such as having had a previous episode of DKA, being unwell with intercurrent illness, or being at risk of dehydration or volume depletion (Type-2 diabetes.pdf, page 70).
# Abstained: False <-- should be False for supported questions
# ================================================================================
# Q15: Should I take aspirin to protect my heart if I have type 2 diabetes?
# A: No, do not take aspirin for primary prevention of cardiovascular disease if you have type 2 diabetes and do not have cardiovascular disease (Type-2 diabetes.pdf, page 119).
# Abstained: False <-- should be False for supported questions
# ================================================================================

# %%
print("===== GENERATION: UNSUPPORTED QUESTIONS =====\n")
for item in unsupported_questions:
    results = retrieve_with_similarity(item["question"], k=4)
    answer = generate_answer(item["question"], results)
    abstained = ABSTAIN_PHRASE in answer.lower()
    print(f"Q{item['number']}: {item['question']}")
    print("Why unsupported:", item["reason"])
    print("A:", answer)
    print("Abstained:", abstained, "<-- should be True for unsupported questions")
    print("=" * 80)
# Out:
# ===== GENERATION: UNSUPPORTED QUESTIONS =====
#
# Q1: How much do diabetes medicines cost in Egypt?
# Why unsupported: No pricing or local market info in either PDF
# A: I don't have enough information in the provided documents to answer that.
# Abstained: True <-- should be True for unsupported questions
# ================================================================================
# Q2: Is there a cure for diabetes now?
# Why unsupported: Not mentioned in either guideline
# A: I don't have enough information in the provided documents to answer that.
# Abstained: True <-- should be True for unsupported questions
# ================================================================================
# Q3: Can people with type 1 diabetes take weight-loss injections like Ozempic?
# Why unsupported: type-1.pdf does not cover this type of medicine at all
# A: I don't have enough information in the provided documents to answer that.
# Abstained: True <-- should be True for unsupported questions
# ================================================================================
# Q4: Will type 1 diabetes affect my chances of having children?
# Why unsupported: type-1.pdf just points to a separate pregnancy guideline, no real answer given
# A: Type 1 diabetes can affect your health, but the guidelines don't say it directly affects your chances of having children. However, there is a mention of pregnancy and a referral to another guideline on diabetes in pregnancy (Type-1 diabetes.pdf, page 23).
# Abstained: False <-- should be True for unsupported questions
# ================================================================================
# Q5: Which brand of blood sugar monitor is the best one to buy?
# Why unsupported: The guidelines don't recommend specific brands or products
# A: I don't have enough information in the provided documents to answer that.
# Abstained: True <-- should be True for unsupported questions
# ================================================================================

# %% [markdown]
# ## 13. Diagnostic: was the official recommendation page actually retrieved?
#
# The generation step can produce a *factually correct* answer while citing a page that isn't the guideline's official recommendation (e.g. a general "Context" section instead of the numbered recommendation). This cell checks, for each supported question, whether `expected_page` was among the retrieved chunk pages at k=4 (what generation used) and at k=6, so you can tell whether the fix is "retrieve more chunks" or something else.

# %%
def diagnose_page_retrieval(item, k_values=(4, 6)):
    """For one question, show whether expected_page appears in the retrieved
    chunk pages at each k, and which chunk/page was actually cited by generation."""
    expected_tag = "type-1" if "type-1" in item["expected_source"] else "type-2"
    expected_page = item["expected_page"]

    print(f"Q{item['number']}: {item['question']}")
    print(f"Expected: {item['expected_source']} p.{expected_page}")

    for k in k_values:
        results = retrieve_with_similarity(item["question"], k=k)
        found_pages = []
        expected_page_present = False

        for doc, score in results:
            doc_name = doc.metadata.get("document_name", "").lower()
            if expected_tag not in doc_name:
                continue
            chunk_pages = _extract_pages(
                doc.metadata.get("page_numbers"),
                doc.metadata.get("page_number"),
            )
            found_pages.extend(chunk_pages)
            if expected_page in chunk_pages:
                expected_page_present = True

        status = "FOUND in top-k" if expected_page_present else "MISSING from top-k"
        print(f"  k={k}: pages retrieved = {sorted(set(found_pages))}  ->  {status}")

    print("=" * 80)


print("===== PAGE-RETRIEVAL DIAGNOSTIC (k=4 vs k=6) =====\n")
for item in supported_questions:
    diagnose_page_retrieval(item)
# Out:
# ===== PAGE-RETRIEVAL DIAGNOSTIC (k=4 vs k=6) =====
#
# Q1: What should my HbA1c number be if I have type 1 diabetes?
# Expected: type-1.pdf p.18
#   k=4: pages retrieved = [17, 18, 29]  ->  FOUND in top-k
#   k=6: pages retrieved = [17, 18, 23, 29]  ->  FOUND in top-k
# ================================================================================
# Q2: How often should I get my HbA1c checked?
# Expected: type-1.pdf p.17
#   k=4: pages retrieved = [17, 22]  ->  FOUND in top-k
#   k=6: pages retrieved = [12, 17, 22, 40]  ->  FOUND in top-k
# ================================================================================
# Q3: What are the signs that someone might have type 1 diabetes?
# Expected: type-1.pdf p.6
#   k=4: pages retrieved = [3, 6, 7, 51]  ->  FOUND in top-k
#   k=6: pages retrieved = [3, 6, 7, 30, 46, 51]  ->  FOUND in top-k
# ================================================================================
# Q4: Can a doctor tell I have type 1 diabetes just from my age or weight?
# Expected: type-1.pdf p.7
#   k=4: pages retrieved = [6, 7, 8, 51, 52]  ->  FOUND in top-k
#   k=6: pages retrieved = [5, 6, 7, 8, 35, 51, 52]  ->  FOUND in top-k
# ================================================================================
# Q5: What kind of insulin plan do people with type 1 diabetes usually start with?
# Expected: type-1.pdf p.24
#   k=4: pages retrieved = [6, 24, 27, 31]  ->  FOUND in top-k
#   k=6: pages retrieved = [6, 24, 27, 31, 39, 60]  ->  FOUND in top-k
# ================================================================================
# Q6: When do I need to check my blood sugar more than 10 times a day?
# Expected: type-1.pdf p.23
#   k=4: pages retrieved = [22, 23]  ->  FOUND in top-k
#   k=6: pages retrieved = [17, 22, 23]  ->  FOUND in top-k
# ================================================================================
# Q7: What should be done if someone with diabetes passes out from low blood sugar?
# Expected: type-1.pdf p.31
#   k=4: pages retrieved = [31, 34]  ->  FOUND in top-k
#   k=6: pages retrieved = [31, 34]  ->  FOUND in top-k
# ================================================================================
# Q8: What blood sugar level should I aim for before an operation?
# Expected: type-1.pdf p.38
#   k=4: pages retrieved = [23, 38]  ->  FOUND in top-k
#   k=6: pages retrieved = [18, 23, 38]  ->  FOUND in top-k
# ================================================================================
# Q9: How often should someone with type 2 diabetes get their HbA1c checked?
# Expected: type-2.pdf p.12
#   k=4: pages retrieved = [12, 113]  ->  FOUND in top-k
#   k=6: pages retrieved = [12, 15, 16, 113]  ->  FOUND in top-k
# ================================================================================
# Q10: Do I need to check my blood sugar every day if I have type 2 diabetes?
# Expected: type-2.pdf p.14
#   k=4: pages retrieved = [14, 16, 113]  ->  FOUND in top-k
#   k=6: pages retrieved = [14, 16, 113, 129]  ->  FOUND in top-k
# ================================================================================
# Q11: What's usually the first medicine given for type 2 diabetes?
# Expected: type-2.pdf p.32
#   k=4: pages retrieved = [26, 69, 71, 129]  ->  MISSING from top-k
#   k=6: pages retrieved = [26, 69, 71, 91, 92, 129]  ->  MISSING from top-k
# ================================================================================
# Q12: What treatment is given if someone has type 2 diabetes and a heart problem?
# Expected: type-2.pdf p.40
#   k=4: pages retrieved = [21, 22, 40, 41, 75]  ->  FOUND in top-k
#   k=6: pages retrieved = [21, 22, 40, 41, 75, 85, 118]  ->  FOUND in top-k
# ================================================================================
# Q13: What treatment options are there for someone with type 2 diabetes who is overweight?
# Expected: type-2.pdf p.58
#   k=4: pages retrieved = [11, 12, 58, 59]  ->  FOUND in top-k
#   k=6: pages retrieved = [11, 12, 22, 58, 59, 71]  ->  FOUND in top-k
# ================================================================================
# Q14: What should be checked before starting SGLT-2 medicine?
# Expected: type-2.pdf p.70
#   k=4: pages retrieved = [69, 70, 71]  ->  FOUND in top-k
#   k=6: pages retrieved = [69, 70, 71]  ->  FOUND in top-k
# ================================================================================
# Q15: Should I take aspirin to protect my heart if I have type 2 diabetes?
# Expected: type-2.pdf p.119
#   k=4: pages retrieved = [52, 119]  ->  FOUND in top-k
#   k=6: pages retrieved = [41, 52, 87, 119]  ->  FOUND in top-k
# ================================================================================
